# %%
#Importamos un archivo de detos de los paises del mundo, actualizados hasta 2023

import pandas as pd
df = pd.read_csv("C:\\Users\\USER\\Desktop\\PARTE2\\world-data-2023.csv", sep=",")

# %%
#Imprimimos ldf.head()as primeras 5 filas del df
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 0           323,000       32.49          93.0              Kabul
# 1             9,000       11.78         355.0             Tirana
# 2           317,000       24.28         213.0            Algiers
# 3               NaN        7.20         376.0   Andorra la Vella
# 4           117,000       40.73         244.0             Luanda
#
#    Co2-Emissions     CPI  ... Official language  \
# 0            NaN   149.9  ...            Pashto
# 1            NaN  119.05  ...          Albanian
# ...

# %%
#Ultimos 5 registros
df.tail()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 190           343,000       17.88          58.0            Caracas
# 191           522,000       16.75          84.0              Hanoi
# 192            40,000       30.45         967.0              Sanaa
# 193            16,000       36.19         260.0             Lusaka
# 194            51,000       30.68         263.0             Harare
#
#      Co2-Emissions       CPI  ... Official language  \
# 190            NaN  2,740.27  ...           Spanish
# ...

# %%
#Listar los nombres de las columnas del dataset
print(df.columns)
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Armed Forces size', 'Birth Rate', 'Calling Code', 'Capital/Major City',
#        'Co2-Emissions', 'CPI', 'CPI Change (%)', 'Currency-Code',
#        'Fertility Rate', 'Forested Area (%)', 'Gasoline Price', 'GDP',
#        'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population: Labor force participation (%)',
#        'Tax revenue (%)', 'Total tax rate', 'Unemployment rate',
#        'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
#Verificamos la estructura del dataset
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Dimensiones del Dataset
print(df.shape)
# Out:
# (195, 35)

# %%
#EJEMPLO: paises con mas emisiones de Co2
df['Co2-Emissions'] = pd.to_numeric(df['Co2-Emissions'], errors='coerce')
df.nlargest(10, 'Co2-Emissions')
# Out:
#                  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 54               Eritrea               35           ER                75.20%
# 160              Somalia               25           SO                70.30%
# 47              Djibouti               43           DJ                73.40%
# 154           Seychelles              214           SC                 3.40%
# 17                Belize               17           BZ                 7.00%
# 5    Antigua and Barbuda              223           AG                20.50%
# 29            Cape Verde              138           CV                19.60%
# 62            The Gambia              239           GM                59.80%
# 27               Burundi              463           BI                79.20%
# 174           East Timor               89           TL                25.60%
#
#     Armed Forces size  Birth Rate  Calling Code      Capital/Major City  \
# ...

# %%
#borramos 2 columnas
columns_to_drop = ['Population',"Land Area(Km2)"]
df.drop(columns_to_drop, axis = "columns", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\USER\Desktop\TRABAJO FINAL PYTHON- LOS 3 PUNTOS\PARTE2\parte2.ipynb Cell 5 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/TRABAJO%20FINAL%20PYTHON-%20LOS%203%20PUNTOS/PARTE2/parte2.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> columns_to_drop = ['Population',"Land Area(Km2)"]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/TRABAJO%20FINAL%20PYTHON-%20LOS%203%20PUNTOS/PARTE2/parte2.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> df.drop(columns_to_drop, axis = "columns", inplace = True)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
#Nuevas dimensiones del Dataset 
print(df.shape)
# Out:
# (195, 33)

# %%
#Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 33 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Armed Forces size                          171 non-null    object
#  5   Birth Rate                                 189 non-null    float64
#  6   Calling Code                               194 non-null    float64
#  7   Capital/Major City                         192 non-null    object
#  8   Co2-Emissions                              30 non-null     float64
#  9   CPI                                        178 non-null    object
# ...

# %%
df.describe()
# Out:
#        Birth Rate  Calling Code  Co2-Emissions  Fertility Rate  \
# count  189.000000    194.000000      30.000000      188.000000
# mean    20.214974    360.546392     326.700000        2.698138
# std      9.945774    323.236419     205.621874        1.282267
# min      5.900000      1.000000      11.000000        0.980000
# 25%     11.300000     82.500000     152.500000        1.705000
# 50%     17.950000    255.500000     257.000000        2.245000
# 75%     28.750000    506.750000     522.750000        3.597500
# max     46.080000   1876.000000     711.000000        6.910000
#
#        Infant mortality  Life expectancy  Maternal mortality ratio  \
# count        189.000000       187.000000                181.000000
# mean          21.332804        72.279679                160.392265
# std           19.548058         7.483661                233.502024
# min            1.400000        52.800000                  2.000000
# ...
